# %%
import itertools
import cv2
import matplotlib.pyplot as plt
import numpy as np
import glob
import math
import json

# %%
thermal_folder = "Thermal//"

data_1 = {}
with open( "data_1.json", "r") as read_file:
    data_1 = json.load(read_file)
    
data_3 = {}
with open("data_3.json", "r") as read_file:
    data_3 = json.load(read_file)

# %%
data = {**data_1, **data_3}
data
# Out:
# {'img_00001.bmp': [[131, 166, 19, 34], [45, 136, 18, 28]],
#  'img_00003.bmp': [[131, 166, 19, 34], [45, 136, 18, 28]],
#  'img_00005.bmp': [[131, 166, 19, 34], [45, 136, 18, 28]],
#  'img_00007.bmp': [[47, 133, 18, 31], [128, 166, 19, 33]],
#  'img_00009.bmp': [[47, 133, 18, 31], [128, 166, 19, 33]],
#  'img_00011.bmp': [[47, 133, 18, 31], [128, 166, 19, 33]],
#  'img_00013.bmp': [[50, 132, 16, 32], [126, 165, 18, 32]],
#  'img_00015.bmp': [[50, 132, 16, 32], [126, 165, 18, 32]],
#  'img_00017.bmp': [[50, 132, 16, 32], [126, 165, 18, 32]],
#  'img_00019.bmp': [[50, 132, 16, 32], [121, 165, 22, 32]],
#  'img_00021.bmp': [[50, 132, 16, 32], [121, 165, 22, 32]],
#  'img_00023.bmp': [[50, 132, 16, 32], [118, 160, 25, 39]],
#  'img_00025.bmp': [[50, 132, 16, 32], [118, 160, 25, 39]],
#  'img_00027.bmp': [[50, 132, 16, 32], [118, 160, 25, 39]],
#  'img_00029.bmp': [[50, 132, 16, 32], [118, 160, 25, 39]],
#  'img_00031.bmp': [[55, 132, 18, 34], [117, 163, 25, 37]],
# ...
