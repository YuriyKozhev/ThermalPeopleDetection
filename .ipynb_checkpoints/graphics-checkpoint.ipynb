# %%
import pandas as pd
import numpy as np
import datetime
import json
import cv2
import matplotlib.pyplot as plt

# metric calculating libraries
from new_metric import main_metric, check_true

# %%
gts_folder = "Groundtruth_Markup//"
preds_folder = "Predictions//"

video_gt = {}
with open(gts_folder + "VIDEO_val_groundtruth.json", "r") as read_file:
    video_gt = json.load(read_file)
    
FLIR_val_gt = {}
with open(gts_folder + "FLIR_val_groundtruth.json", "r") as read_file:
    FLIR_val_gt = json.load(read_file)
    
############
  
video_preds = {}
with open(preds_folder + "VIDEO_val_predictions_TSMO_SVM_or_TSMO_SSD_or_SSD.json", "r") as read_file:
    video_preds = json.load(read_file)
    
FLIR_val_preds = {}
with open(preds_folder + "FLIR_val_predictions_TSMO_SVM_or_TSMO_SSD_or_SSD.json", "r") as read_file:
    FLIR_val_preds = json.load(read_file)

# %%
metric_type = 'modified'

# %%
# %%time
columns = ['Frame_Number', 'FLIR0_Video1', 'Object_Index', 'Start_Time', 'Detected', 'Max_Intersected_CNT', 'IOU', 
          'X', 'Y', 'W', 'H', 'Frame_Int', 'GT_Int']
video_gt_table = pd.DataFrame(columns=columns)
video_gt_table = video_gt_table.astype({"Frame_Number": str, 'FLIR0_Video1': np.bool,
               'Object_Index': np.uint8, "Start_Time": np.datetime64, 'Detected': np.bool,
               'Max_Intersected_CNT': np.uint8, 'IOU': np.float, 'X': np.uint8, 'Y': np.uint8,
               'W': np.uint8, 'H': np.uint8, 'Frame_Int': np.float, 'GT_Int': np.float})


columns = ['Frame_Number', 'FLIR0_Video1', 'Object_Index', 'Start_Time', 'True_False_Plus', 'True_False_Minus', 'Intersected_GTs', 'IOUs',
           'X', 'Y', 'W', 'H', 'Frame_Int', 'CNT_Int', 'Canny']
video_pred_table = pd.DataFrame(columns=columns)
video_pred_table = video_pred_table.astype({"Frame_Number": str, 'FLIR0_Video1': np.bool,
               'Object_Index': np.uint8, "Start_Time": np.datetime64, 'True_False_Plus': np.bool, 'True_False_Minus': np.bool,
               'Intersected_GTs': object, 'IOUs': object, 'X': np.uint8, 'Y': np.uint8,
               'W': np.uint8, 'H': np.uint8, 'Frame_Int': np.uint8, 'CNT_Int': np.float, 'Canny': np.float})


for im_path in list(video_gt.keys()):
    gts = video_gt[im_path]
    frame = cv2.imread(im_path, 0)
    frame_int = frame.mean()
    
    if im_path in list(video_preds.keys()):
        preds = video_preds[im_path]
    else:
        preds = []
        
    table = main_metric(gts, preds, frame.shape)
    
    maximums = []
    for i, gt in enumerate(gts):
        max_Iou = 0
        x,y,w,h = gt
        gt_int = frame[y:y+h,x:x+w].mean()
        if table.shape[0] * table.shape[1] != 0 :
            
            
            IoUs = table[i,:,0]
            IoOs = table[i,:,1]
            
            max_IoU = IoUs.max()
            max_IoO = IoOs.max()
            
            max_cnt = None
            
            is_true = check_true(IoUs, IoOs, metric_type)
            
        else:
            max_IoU = 0
            max_IoO = 0
            max_cnt = None
            is_true = False
            
        maximums.append(round(max_IoU, 3))

        video_gt_table = video_gt_table.append(pd.Series(
                        ['Video_'+im_path[-9:-5], True, i, pd.Timestamp('now'), is_true, max_cnt, max_IoU, 
                             x, y, w, h, frame_int, gt_int]
                            , index=video_gt_table.columns), ignore_index=True)
        
    for j, pred in enumerate(preds):
        x,y,w,h = pred
        pred_int = frame[y:y+h,x:x+w].mean()
        if table.shape[0] * table.shape[1] != 0 :
            IoUs = table[:,j,0]
            IoOs = table[:,j,1]
            
            max_IoU = IoUs.max()
            max_IoO = IoOs.max()
            is_true = check_true(IoUs, IoOs, metric_type)
            
            is_true_m = False
            
            
            for iou in IoUs:
                if round(iou,3) in maximums and is_true:
                    is_true_m = True
                
            intersected_gts = None
            IoUs = None
        else:
            max_IoU = 0
            max_IoO = None
            intersected_gts = None
            IoUs = None
            is_true = False
            is_true_m = False
        video_pred_table = video_pred_table.append(pd.Series(
                ['Video_'+im_path[-9:-5], True, j, pd.Timestamp('now'), is_true, is_true_m, 
                 intersected_gts, IoUs, x, y, w, h, frame_int, pred_int, 0]
                , index=video_pred_table.columns), ignore_index=True)
# Out:
# Wall time: 1min

# %%
display(video_gt_table)
display(video_pred_table)
# Out:
#      Frame_Number  FLIR0_Video1  Object_Index                 Start_Time  \
# 0      Video_1500          True             0 2020-07-23 19:51:13.604890
# 1      Video_1500          True             1 2020-07-23 19:51:13.620893
# 2      Video_1500          True             2 2020-07-23 19:51:13.636895
# 3      Video_1501          True             0 2020-07-23 19:51:13.767675
# 4      Video_1501          True             1 2020-07-23 19:51:13.775908
# ...           ...           ...           ...                        ...
# 1449   Video_8228          True             0 2020-07-23 19:52:13.325274
# 1450   Video_8229          True             0 2020-07-23 19:52:13.347788
# 1451   Video_8230          True             0 2020-07-23 19:52:13.370083
# 1452   Video_8231          True             0 2020-07-23 19:52:13.397610
# 1453   Video_8232          True             0 2020-07-23 19:52:13.419649
#
#       Detected Max_Intersected_CNT       IOU    X    Y   W    H  Frame_Int  \
# 0         True                None  0.843201  509  148  82  173  93.745501
# 1         True                None  0.555400  564   81  22   36  93.745501
# 2         True                None  0.500000  551   80  17   37  93.745501
# 3         True                None  0.843201  509  148  82  173  93.719501
# 4         True                None  0.538043  564   81  22   36  93.719501
# ...        ...                 ...       ...  ...  ...  ..  ...        ...
# 1449      True                None  0.604058  857  129  57  113  95.827541
# 1450      True                None  0.721211  871  132  51  113  96.892685
# 1451      True                None  0.698785  878  134  46  105  97.260321
# 1452     False                None  0.258650  892  134  31  106  97.662397
# 1453     False                None  0.000000  898  142  27   98  98.009252
#
#           GT_Int
# 0     111.821655
# 1     137.731061
# 2     175.394277
# 3     111.821585
# 4     136.877525
# ...          ...
# 1449   94.783574
# 1450   94.633524
# 1451   92.808489
# 1452  103.525867
# 1453   91.490552
#
# [1454 rows x 13 columns]
#      Frame_Number  FLIR0_Video1  Object_Index                 Start_Time  \
# 0      Video_1500          True             0 2020-07-23 19:51:13.662443
# 1      Video_1500          True             1 2020-07-23 19:51:13.671652
# 2      Video_1500          True             2 2020-07-23 19:51:13.687659
# 3      Video_1500          True             3 2020-07-23 19:51:13.703877
# 4      Video_1500          True             4 2020-07-23 19:51:13.711664
# ...           ...           ...           ...                        ...
# 3894   Video_8237          True             0 2020-07-23 19:52:13.457923
# 3895   Video_8237          True             1 2020-07-23 19:52:13.470317
# 3896   Video_8238          True             0 2020-07-23 19:52:13.482356
# 3897   Video_8240          True             0 2020-07-23 19:52:13.500348
# 3898   Video_8245          True             0 2020-07-23 19:52:13.532643
#
#       True_False_Plus  True_False_Minus Intersected_GTs  IOUs    X    Y   W  \
# 0                True              True            None  None  561   78  31
# 1                True             False            None  None  546   76  27
# 2                True             False            None  None  501  145  90
# 3                True              True            None  None  502  156  90
# 4                True             False            None  None  543   73  49
# ...               ...               ...             ...   ...  ...  ...  ..
# 3894            False             False            None  None  468  479  28
# 3895            False             False            None  None  172  436  36
# 3896            False             False            None  None  172  436  37
# 3897            False             False            None  None  172  436  37
# 3898            False             False            None  None  888  153  40
#
#         H   Frame_Int     CNT_Int  Canny
# 0      46   93.745501  123.982468    0.0
# 1      49   93.745501  143.433862    0.0
# 2     192   93.745501   99.895833    0.0
# 3     171   93.745501  105.918259    0.0
# 4      54   93.745501  123.684429    0.0
# ...   ...         ...         ...    ...
# 3894   38   98.772479  123.080827    0.0
# 3895   42   98.772479  146.922619    0.0
# 3896   42   99.237901  143.689833    0.0
# 3897   42  100.039128  144.139640    0.0
# 3898   26  100.616876  131.341346    0.0
#
# [3899 rows x 15 columns]

# %%
print("Ошибка 2 рода: ", 1 - video_gt_table['Detected'].sum()/video_gt_table['Detected'].count(), 
     "Ошибка 1 рода minus: ", 1 - video_pred_table['True_False_Minus'].sum()/video_pred_table['True_False_Minus'].count(),
     "Ошибка 1 рода plus: ", 1 - video_pred_table['True_False_Plus'].sum()/video_pred_table['True_False_Plus'].count(),
     "Количество ложноположительных контуров plus: ", video_pred_table['True_False_Plus'].count() - video_pred_table['True_False_Plus'].sum(),
     "Количество ложноположительных контуров minus: ", video_pred_table['True_False_Minus'].count() - video_pred_table['True_False_Minus'].sum())
# Out:
# Ошибка 2 рода:  0.06946354883081152 Ошибка 1 рода minus:  0.6152859707617337 Ошибка 1 рода plus:  0.35675814311361886 Количество ложноположительных контуров plus:  1391 Количество ложноположительных контуров minus:  2399

# %%
names = []
for im_path in list(video_gt.keys()):
    names.append('Video_'+im_path[-9:-5])

names1 = list(video_gt_table.groupby(['Frame_Number'])['Frame_Number'])
names2 = list(video_pred_table.groupby(['Frame_Number'])['Frame_Number'])

table1_names = []
table2_names = []

for i in range(names1.__len__()):
    table1_names.append(names1[i][0])
    
for i in range(names2.__len__()):
    table2_names.append(names2[i][0])
    
arr1 = []

for name in names:
    if name in table1_names:
        arr1.append(video_gt_table[video_gt_table['Frame_Number'] == name].count()[0])
    else:
        arr1.append(0)
        
arr2 = []

for name in names:
    if name in table1_names:
        arr2.append(video_gt_table[video_gt_table['Frame_Number'] == name].sum().Detected)
    else:
        arr2.append(0)
        
arr3 = []

for name in names:
    if name in table2_names:
        arr3.append(video_pred_table[video_pred_table['Frame_Number'] == name].count()[0] - video_pred_table[video_pred_table['Frame_Number'] == name].sum().True_False_Plus)
    else:
        arr3.append(0)
        
# %matplotlib notebook

# plt.figure(figsize=(6,4))
x = np.arange(0, 500, 1)
#  всего объектов
plt.plot(x, arr1, color = 'g', linewidth = 12, label='всего объектов')
# задетектировано верно
plt.plot(x, arr2, color = 'b', linewidth = 3, label='задетектировано верно')
# всего контуров нарисованно
plt.plot(x, arr3, color = 'r', label='всего контуров нарисованно')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %%time

columns = ['Frame_Number', 'FLIR0_Video1', 'Object_Index', 'Start_Time', 'Detected', 'Max_Intersected_CNT', 'IOU', 
          'X', 'Y', 'W', 'H', 'Frame_Int', 'GT_Int']
gt_table = pd.DataFrame(columns=columns)
gt_table = gt_table.astype({"Frame_Number": str, 'FLIR0_Video1': np.bool,
               'Object_Index': np.uint8, "Start_Time": np.datetime64, 'Detected': np.bool,
               'Max_Intersected_CNT': np.uint8, 'IOU': np.float, 'X': np.uint8, 'Y': np.uint8,
               'W': np.uint8, 'H': np.uint8, 'Frame_Int': np.float, 'GT_Int': np.float})


columns = ['Frame_Number', 'FLIR0_Video1', 'Object_Index', 'Start_Time', 'True_False_Plus', 'True_False_Minus', 'Intersected_GTs', 'IOUs',
           'X', 'Y', 'W', 'H', 'Frame_Int', 'CNT_Int', 'Canny']
pred_table = pd.DataFrame(columns=columns)
pred_table = pred_table.astype({"Frame_Number": str, 'FLIR0_Video1': np.bool,
               'Object_Index': np.uint8, "Start_Time": np.datetime64, 'True_False_Plus': np.bool, 'True_False_Minus': np.bool,
               'Intersected_GTs': object, 'IOUs': object, 'X': np.uint8, 'Y': np.uint8,
               'W': np.uint8, 'H': np.uint8, 'Frame_Int': np.uint8, 'CNT_Int': np.float, 'Canny': np.float})


for im_path in list(FLIR_val_gt.keys()):
    gts = FLIR_val_gt[im_path]
    frame = cv2.imread(im_path, 0)
    frame_int = frame.mean()
    
    if im_path in list(FLIR_val_preds.keys()):
        preds = FLIR_val_preds[im_path]
    else:
        preds = []
    
    table = main_metric(gts, preds, frame.shape)

    maximums = []
    for i, gt in enumerate(gts):
        x,y,w,h = gt
        gt_int = frame[y:y+h,x:x+w].mean()
        if table.shape[0] * table.shape[1] != 0 :
            IoUs = table[i,:,0]
            IoOs = table[i,:,1]
            
            max_IoU = IoUs.max()
            max_IoO = IoOs.max()
            
            max_cnt = None
            
            is_true = check_true(IoUs, IoOs, metric_type)
            
        else:
            max_IoU = 0
            max_IoO = 0
            max_cnt = None
            is_true = False
        
        maximums.append(round(max_IoU, 3))
        
        gt_table = gt_table.append(pd.Series(
                        ['FLIR_'+im_path[-9:-5], False, i, pd.Timestamp('now'), is_true, max_cnt, max_IoU, 
                             x, y, w, h, frame_int, gt_int]
                            , index=gt_table.columns), ignore_index=True)
        
    for j, pred in enumerate(preds):
        x,y,w,h = pred
        pred_int = frame[y:y+h,x:x+w].mean()
        if table.shape[0] * table.shape[1] != 0 :
            IoUs = table[:,j,0]
            IoOs = table[:,j,1]
            
            max_IoU = IoUs.max()
            max_IoO = IoOs.max()
            is_true = check_true(IoUs, IoOs, metric_type)
            
            is_true_m = False
            
            for iou in IoUs:
                if round(iou,3) in maximums and is_true:
                    is_true_m = True
                
            
            intersected_gts = None
            IoUs = None
        else:
            max_IoU = 0
            max_IoO = None
            intersected_gts = None
            IoUs = None
            is_true = False
            is_true_m = False
            
        pred_table = pred_table.append(pd.Series(
                ['FLIR_'+im_path[-9:-5], False, j, pd.Timestamp('now'), is_true, is_true_m,
                 intersected_gts, IoUs, x, y, w, h, frame_int, pred_int, 0]
                , index=pred_table.columns), ignore_index=True)
# Out:
# Wall time: 53.4 s

# %%
display(gt_table)
display(pred_table)
# Out:
#      Frame_Number  FLIR0_Video1  Object_Index                 Start_Time  \
# 0       FLIR_8863         False             0 2020-07-21 16:37:05.127518
# 1       FLIR_8863         False             1 2020-07-21 16:37:05.136521
# 2       FLIR_8864         False             0 2020-07-21 16:37:05.201523
# 3       FLIR_8864         False             1 2020-07-21 16:37:05.209527
# 4       FLIR_8864         False             2 2020-07-21 16:37:05.219528
# ...           ...           ...           ...                        ...
# 2138    FLIR_9651         False             0 2020-07-21 16:37:58.045510
# 2139    FLIR_9651         False             1 2020-07-21 16:37:58.054514
# 2140    FLIR_9652         False             0 2020-07-21 16:37:58.079516
# 2141    FLIR_9652         False             1 2020-07-21 16:37:58.087518
# 2142    FLIR_9652         False             2 2020-07-21 16:37:58.096516
#
#       Detected Max_Intersected_CNT       IOU    X    Y   W    H   Frame_Int  \
# 0         True                None  0.686275  580  206  34   75  140.909201
# 1         True                None  0.799632  609  207  30  116  140.909201
# 2         True                None  0.813173  369  193  74  126  127.433084
# 3         True                None  0.813969  488  192  49  134  127.433084
# 4         True                None  0.734940  544  200  32  104  127.433084
# ...        ...                 ...       ...  ...  ...  ..  ...         ...
# 2138      True                None  0.643928  114  188  40  137  136.708417
# 2139      True                None  0.643928  152  167  60  187  136.708417
# 2140      True                None  0.447099  410  215  24   56  131.505838
# 2141      True                None  0.595570  433  216  13   55  131.505838
# 2142      True                None  0.759669  443  213  15   56  131.505838
#
#           GT_Int
# 0     209.165098
# 1     215.918103
# 2     141.401652
# 3     172.186567
# 4     202.148438
# ...          ...
# 2138  212.900000
# 2139  211.818806
# 2140  210.787202
# 2141  215.061538
# 2142  216.172619
#
# [2143 rows x 13 columns]
#      Frame_Number  FLIR0_Video1  Object_Index                 Start_Time  \
# 0       FLIR_8863         False             0 2020-07-21 16:37:05.148519
# 1       FLIR_8863         False             1 2020-07-21 16:37:05.159523
# 2       FLIR_8863         False             2 2020-07-21 16:37:05.167520
# 3       FLIR_8863         False             3 2020-07-21 16:37:05.175522
# 4       FLIR_8863         False             4 2020-07-21 16:37:05.183523
# ...           ...           ...           ...                        ...
# 4067    FLIR_9666         False             0 2020-07-21 16:37:58.466402
# 4068    FLIR_9666         False             1 2020-07-21 16:37:58.473403
# 4069    FLIR_9667         False             0 2020-07-21 16:37:58.486404
# 4070    FLIR_9667         False             1 2020-07-21 16:37:58.493405
# 4071    FLIR_9668         False             0 2020-07-21 16:37:58.505406
#
#       True_False_Plus  True_False_Minus Intersected_GTs  IOUs    X    Y    W  \
# 0               False             False            None  None  522  224   12
# 1                True              True            None  None  608  191   32
# 2                True              True            None  None  588  211   25
# 3               False             False            None  None    0  155  640
# 4               False             False            None  None    0  155  640
# ...               ...               ...             ...   ...  ...  ...  ...
# 4067            False             False            None  None  329  216   30
# 4068            False             False            None  None   72  208  216
# 4069            False             False            None  None  142  171   27
# 4070            False             False            None  None  400  237   24
# 4071            False             False            None  None  256  225  144
#
#         H   Frame_Int     CNT_Int  Canny
# 0      25  140.909201  172.613333    0.0
# 1     136  140.909201  216.428768    0.0
# 2      70  140.909201  222.835429    0.0
# 3     357  140.909201  171.957493    0.0
# 4     357  140.909201  171.957493    0.0
# ...   ...         ...         ...    ...
# 4067   25  128.855215  115.964000    0.0
# 4068  115  128.855215  157.926006    0.0
# 4069   64  141.592252  137.226273    0.0
# 4070   30  141.592252  162.098611    0.0
# 4071   76  132.373392  168.687957    0.0
#
# [4072 rows x 15 columns]

# %%
print("Ошибка 2 рода: ", 1 - gt_table['Detected'].sum()/gt_table['Detected'].count(), 
     "Ошибка 1 рода minus: ", 1 - pred_table['True_False_Minus'].sum()/pred_table['True_False_Minus'].count(),
     "Ошибка 1 рода plus: ", 1 - pred_table['True_False_Plus'].sum()/pred_table['True_False_Plus'].count(),
     "Количество ложноположительных контуров plus: ", pred_table['True_False_Plus'].count() - pred_table['True_False_Plus'].sum(),
     "Количество ложноположительных контуров minus: ", pred_table['True_False_Minus'].count() - pred_table['True_False_Minus'].sum())
# Out:
# Ошибка 2 рода:  0.17825478301446573 Ошибка 1 рода minus:  0.5034381139489195 Ошибка 1 рода plus:  0.2843811394891945 Количество ложноположительных контуров plus:  1158 Количество ложноположительных контуров minus:  2050

# %%
names = []
for im_path in list(FLIR_val_gt.keys()):
    names.append('FLIR_'+im_path[-9:-5])
    
names1 = list(gt_table.groupby(['Frame_Number'])['Frame_Number'])
names2 = list(pred_table.groupby(['Frame_Number'])['Frame_Number'])

table1_names = []
table2_names = []

for i in range(names1.__len__()):
    table1_names.append(names1[i][0])
    
for i in range(names2.__len__()):
    table2_names.append(names2[i][0])
    
arr1 = []

for name in names:
    if name in table1_names:
        arr1.append(gt_table[gt_table['Frame_Number'] == name].count()[0])
    else:
        arr1.append(0)
        
arr2 = []

for name in names:
    if name in table1_names:
        arr2.append(gt_table[gt_table['Frame_Number'] == name].sum().Detected)
    else:
        arr2.append(0)
        
arr3 = []

for name in names:
    if name in table2_names:
        arr3.append(pred_table[pred_table['Frame_Number'] == name].count()[0] - pred_table[pred_table['Frame_Number'] == name].sum().True_False_Plus)
    else:
        arr3.append(0)
        
# %matplotlib notebook

# plt.figure(figsize=(6,4))
x = np.arange(0, 502, 1)
#  всего объектов
plt.plot(x, arr1, color = 'g', linewidth = 12, label='всего объектов')
# задетектировано верно
plt.plot(x, arr2, color = 'b', linewidth = 3, label='задетектировано верно')
# всего контуров нарисованно
plt.plot(x, arr3, color = 'r', label='всего контуров нарисованно')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

# %%
def vis_video(video_path):
    video_preds = {}
    with open(preds_folder + video_path, "r") as read_file:
        video_preds = json.load(read_file)
    
    metric_type = 'modified'

    columns = ['Frame_Number', 'FLIR0_Video1', 'Object_Index', 'Start_Time', 'Detected', 'Max_Intersected_CNT', 'IOU', 
              'X', 'Y', 'W', 'H', 'Frame_Int', 'GT_Int']
    video_gt_table = pd.DataFrame(columns=columns)
    video_gt_table = video_gt_table.astype({"Frame_Number": str, 'FLIR0_Video1': np.bool,
                   'Object_Index': np.uint8, "Start_Time": np.datetime64, 'Detected': np.bool,
                   'Max_Intersected_CNT': np.uint8, 'IOU': np.float, 'X': np.uint8, 'Y': np.uint8,
                   'W': np.uint8, 'H': np.uint8, 'Frame_Int': np.float, 'GT_Int': np.float})


    columns = ['Frame_Number', 'FLIR0_Video1', 'Object_Index', 'Start_Time', 'True_False_Plus', 'True_False_Minus', 'Intersected_GTs', 'IOUs',
               'X', 'Y', 'W', 'H', 'Frame_Int', 'CNT_Int', 'Canny']
    video_pred_table = pd.DataFrame(columns=columns)
    video_pred_table = video_pred_table.astype({"Frame_Number": str, 'FLIR0_Video1': np.bool,
                   'Object_Index': np.uint8, "Start_Time": np.datetime64, 'True_False_Plus': np.bool, 'True_False_Minus': np.bool,
                   'Intersected_GTs': object, 'IOUs': object, 'X': np.uint8, 'Y': np.uint8,
                   'W': np.uint8, 'H': np.uint8, 'Frame_Int': np.uint8, 'CNT_Int': np.float, 'Canny': np.float})


    for im_path in list(video_gt.keys()):
        gts = video_gt[im_path]
        frame = cv2.imread(im_path, 0)
        frame_int = frame.mean()

        if im_path in list(video_preds.keys()):
            preds = video_preds[im_path]
        else:
            preds = []

        table = main_metric(gts, preds, frame.shape)

        maximums = []
        for i, gt in enumerate(gts):
            max_Iou = 0
            x,y,w,h = gt
            gt_int = frame[y:y+h,x:x+w].mean()
            if table.shape[0] * table.shape[1] != 0 :


                IoUs = table[i,:,0]
                IoOs = table[i,:,1]

                max_IoU = IoUs.max()
                max_IoO = IoOs.max()

                max_cnt = None

                is_true = check_true(IoUs, IoOs, metric_type)

            else:
                max_IoU = 0
                max_IoO = 0
                max_cnt = None
                is_true = False

            maximums.append(round(max_IoU, 3))

            video_gt_table = video_gt_table.append(pd.Series(
                            ['Video_'+im_path[-9:-5], True, i, pd.Timestamp('now'), is_true, max_cnt, max_IoU, 
                                 x, y, w, h, frame_int, gt_int]
                                , index=video_gt_table.columns), ignore_index=True)

        for j, pred in enumerate(preds):
            x,y,w,h = pred
            pred_int = frame[y:y+h,x:x+w].mean()
            if table.shape[0] * table.shape[1] != 0 :
                IoUs = table[:,j,0]
                IoOs = table[:,j,1]

                max_IoU = IoUs.max()
                max_IoO = IoOs.max()
                is_true = check_true(IoUs, IoOs, metric_type)

                is_true_m = False


                for iou in IoUs:
                    if round(iou,3) in maximums and is_true:
                        is_true_m = True

                intersected_gts = None
                IoUs = None
            else:
                max_IoU = 0
                max_IoO = None
                intersected_gts = None
                IoUs = None
                is_true = False
                is_true_m = False
            video_pred_table = video_pred_table.append(pd.Series(
                    ['Video_'+im_path[-9:-5], True, j, pd.Timestamp('now'), is_true, is_true_m, 
                     intersected_gts, IoUs, x, y, w, h, frame_int, pred_int, 0]
                    , index=video_pred_table.columns), ignore_index=True)
            
    names = []
    for im_path in list(video_gt.keys()):
        names.append('Video_'+im_path[-9:-5])

    names1 = list(video_gt_table.groupby(['Frame_Number'])['Frame_Number'])
    names2 = list(video_pred_table.groupby(['Frame_Number'])['Frame_Number'])

    table1_names = []
    table2_names = []

    for i in range(names1.__len__()):
        table1_names.append(names1[i][0])

    for i in range(names2.__len__()):
        table2_names.append(names2[i][0])

    arr1 = []

    for name in names:
        if name in table1_names:
            arr1.append(video_gt_table[video_gt_table['Frame_Number'] == name].count()[0])
        else:
            arr1.append(0)

    arr2 = []

    for name in names:
        if name in table1_names:
            arr2.append(video_gt_table[video_gt_table['Frame_Number'] == name].sum().Detected)
        else:
            arr2.append(0)

    arr3 = []

    for name in names:
        if name in table2_names:
            arr3.append(video_pred_table[video_pred_table['Frame_Number'] == name].count()[0] - video_pred_table[video_pred_table['Frame_Number'] == name].sum().True_False_Plus)
        else:
            arr3.append(0)

    return (x, arr1, arr2, arr3)

# %%
def vis_FLIR(FLIR_path):
    FLIR_val_preds = {}
    with open(preds_folder + FLIR_path, "r") as read_file:
        FLIR_val_preds = json.load(read_file)
    
    metric_type = 'modified'

    columns = ['Frame_Number', 'FLIR0_Video1', 'Object_Index', 'Start_Time', 'Detected', 'Max_Intersected_CNT', 'IOU', 
              'X', 'Y', 'W', 'H', 'Frame_Int', 'GT_Int']
    gt_table = pd.DataFrame(columns=columns)
    gt_table = gt_table.astype({"Frame_Number": str, 'FLIR0_Video1': np.bool,
                   'Object_Index': np.uint8, "Start_Time": np.datetime64, 'Detected': np.bool,
                   'Max_Intersected_CNT': np.uint8, 'IOU': np.float, 'X': np.uint8, 'Y': np.uint8,
                   'W': np.uint8, 'H': np.uint8, 'Frame_Int': np.float, 'GT_Int': np.float})


    columns = ['Frame_Number', 'FLIR0_Video1', 'Object_Index', 'Start_Time', 'True_False_Plus', 'True_False_Minus', 'Intersected_GTs', 'IOUs',
               'X', 'Y', 'W', 'H', 'Frame_Int', 'CNT_Int', 'Canny']
    pred_table = pd.DataFrame(columns=columns)
    pred_table = pred_table.astype({"Frame_Number": str, 'FLIR0_Video1': np.bool,
                   'Object_Index': np.uint8, "Start_Time": np.datetime64, 'True_False_Plus': np.bool, 'True_False_Minus': np.bool,
                   'Intersected_GTs': object, 'IOUs': object, 'X': np.uint8, 'Y': np.uint8,
                   'W': np.uint8, 'H': np.uint8, 'Frame_Int': np.uint8, 'CNT_Int': np.float, 'Canny': np.float})


    for im_path in list(FLIR_val_gt.keys()):
        gts = FLIR_val_gt[im_path]
        frame = cv2.imread(im_path, 0)
        frame_int = frame.mean()

        if im_path in list(FLIR_val_preds.keys()):
            preds = FLIR_val_preds[im_path]
        else:
            preds = []

        table = main_metric(gts, preds, frame.shape)

        maximums = []
        for i, gt in enumerate(gts):
            x,y,w,h = gt
            gt_int = frame[y:y+h,x:x+w].mean()
            if table.shape[0] * table.shape[1] != 0 :
                IoUs = table[i,:,0]
                IoOs = table[i,:,1]

                max_IoU = IoUs.max()
                max_IoO = IoOs.max()

                max_cnt = None

                is_true = check_true(IoUs, IoOs, metric_type)

            else:
                max_IoU = 0
                max_IoO = 0
                max_cnt = None
                is_true = False

            maximums.append(round(max_IoU, 3))

            gt_table = gt_table.append(pd.Series(
                            ['FLIR_'+im_path[-9:-5], False, i, pd.Timestamp('now'), is_true, max_cnt, max_IoU, 
                                 x, y, w, h, frame_int, gt_int]
                                , index=gt_table.columns), ignore_index=True)

        for j, pred in enumerate(preds):
            x,y,w,h = pred
            pred_int = frame[y:y+h,x:x+w].mean()
            if table.shape[0] * table.shape[1] != 0 :
                IoUs = table[:,j,0]
                IoOs = table[:,j,1]

                max_IoU = IoUs.max()
                max_IoO = IoOs.max()
                is_true = check_true(IoUs, IoOs, metric_type)

                is_true_m = False

                for iou in IoUs:
                    if round(iou,3) in maximums and is_true:
                        is_true_m = True


                intersected_gts = None
                IoUs = None
            else:
                max_IoU = 0
                max_IoO = None
                intersected_gts = None
                IoUs = None
                is_true = False
                is_true_m = False

            pred_table = pred_table.append(pd.Series(
                    ['FLIR_'+im_path[-9:-5], False, j, pd.Timestamp('now'), is_true, is_true_m,
                     intersected_gts, IoUs, x, y, w, h, frame_int, pred_int, 0]
                    , index=pred_table.columns), ignore_index=True)
    names = []
    for im_path in list(FLIR_val_gt.keys()):
        names.append('FLIR_'+im_path[-9:-5])

    names1 = list(gt_table.groupby(['Frame_Number'])['Frame_Number'])
    names2 = list(pred_table.groupby(['Frame_Number'])['Frame_Number'])

    table1_names = []
    table2_names = []

    for i in range(names1.__len__()):
        table1_names.append(names1[i][0])

    for i in range(names2.__len__()):
        table2_names.append(names2[i][0])

    arr1 = []

    for name in names:
        if name in table1_names:
            arr1.append(gt_table[gt_table['Frame_Number'] == name].count()[0])
        else:
            arr1.append(0)

    arr2 = []

    for name in names:
        if name in table1_names:
            arr2.append(gt_table[gt_table['Frame_Number'] == name].sum().Detected)
        else:
            arr2.append(0)

    arr3 = []

    for name in names:
        if name in table2_names:
            arr3.append(pred_table[pred_table['Frame_Number'] == name].count()[0] - pred_table[pred_table['Frame_Number'] == name].sum().True_False_Plus)
        else:
            arr3.append(0)

    return (x, arr1, arr2, arr3)

# %%
x, arr1, arr2, arr3 = vis_video("VIDEO_val_predictions_TSMO_SVM_or_TSMO_SSD_or_SSD.json")

plt.figure(figsize=(16, 12))
x = np.arange(0, 500, 1)
#  всего объектов
plt.plot(x, arr1, color = 'g', linewidth = 12, label='всего объектов')
# задетектировано верно
plt.plot(x, arr2, color = 'b', linewidth = 3, label='задетектировано верно')
# всего контуров нарисованно
plt.plot(x, arr3, color = 'r', label='всего контуров нарисованно')
plt.legend()
plt.show()

# %%
x, arr1, arr2, arr3 = vis_FLIR("FLIR_val_predictions_TSMO_SVM_or_TSMO_SSD_or_SSD.json")

plt.figure(figsize=(16, 12))
x = np.arange(0, 502, 1)
#  всего объектов
plt.plot(x, arr1, color = 'g', linewidth = 12, label='всего объектов')
# задетектировано верно
plt.plot(x, arr2, color = 'b', linewidth = 3, label='задетектировано верно')
# всего контуров нарисованно
plt.plot(x, arr3, color = 'r', label='всего контуров нарисованно')
plt.legend()
plt.show()

# %%
x, arr1, arr2, arr3 = vis_video("VIDEO_val_predictions_TSMO_SVM_or_SSD.json")

plt.figure(figsize=(16, 12))
x = np.arange(0, 500, 1)
#  всего объектов
plt.plot(x, arr1, color = 'g', linewidth = 12, label='всего объектов')
# задетектировано верно
plt.plot(x, arr2, color = 'b', linewidth = 3, label='задетектировано верно')
# всего контуров нарисованно
plt.plot(x, arr3, color = 'r', label='всего контуров нарисованно')
plt.legend()
plt.show()

# %%
x, arr1, arr2, arr3 = vis_FLIR("FLIR_val_predictions_TSMO_SVM_or_SSD.json")

plt.figure(figsize=(16, 12))
x = np.arange(0, 502, 1)
#  всего объектов
plt.plot(x, arr1, color = 'g', linewidth = 12, label='всего объектов')
# задетектировано верно
plt.plot(x, arr2, color = 'b', linewidth = 3, label='задетектировано верно')
# всего контуров нарисованно
plt.plot(x, arr3, color = 'r', label='всего контуров нарисованно')
plt.legend()
plt.show()
